# %% [markdown]
# # 01 - Data Collection
#
# Pull historical stats and advanced metrics using pybaseball.
#
# ## Data Sources
# - **Base stats**: `pybaseball.batting_stats()` / `pitching_stats()` from FanGraphs
# - **Statcast metrics**: `statcast_batter_expected_stats()` / `statcast_pitcher_expected_stats()`
# - **Pitch characteristics**: pitch speed, spin, break, usage from Baseball Savant
# - **External projections**: for PA/IP estimates (Steamer, ZiPS, etc.)

# %%
import sys
sys.path.insert(0, '..')

from src.data.collect import *
from config.settings import *

# %% [markdown]
# ## Batting Stats

# %%
# TODO: collect batting stats

# %% [markdown]
# ## Pitching Stats

# %%
# TODO: collect pitching stats

# %% [markdown]
# ## Statcast Metrics

# %%
# TODO: collect Statcast batter and pitcher metrics
