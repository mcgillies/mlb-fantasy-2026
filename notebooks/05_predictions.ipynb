# %% [markdown]
# # 05 - Predictions & Rankings
#
# Generate 2026 fantasy point predictions:
# 1. Predict rate stats (Fpoints/PA, Fpoints/IP) using 2025 metrics
# 2. Scale to totals using projected PA/IP from external systems
# 3. Generate positional and overall rankings
# 4. Compare with expert projections

# %%
import sys
sys.path.insert(0, '..')

from src.models.predict import *
from src.models.train import load_model
from src.viz.plots import *

# %%
# TODO: generate predictions, scale, rank, save
