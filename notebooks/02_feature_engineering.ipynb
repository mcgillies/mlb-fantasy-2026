# %% [markdown]
# # 02 - Feature Engineering
#
# - Calculate fantasy points from base stats
# - Merge stats with advanced metrics (lagged by 1 year)
# - Create lag features (1-2 year lookback)
# - Handle missing data (rookies, injured players)
# - Build final feature matrices for batter and pitcher models

# %%
import sys
sys.path.insert(0, '..')

from src.data.fantasy_points import *
from src.data.process import *
from src.data.features import *
from src.utils.imputation import *
from config.settings import *

# %%
# TODO: load raw data, calculate fpoints, merge, engineer features
